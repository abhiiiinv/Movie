# %%
import pandas as pd
df=pd.read_csv("movies_metadata.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %%
df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
df= df[df["status"] == "Released"]
df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
df=df.drop(columns=['belongs_to_collection','genres','homepage','imdb_id','original_title','spoken_languages','tagline','title','overview','poster_path','production_companies','production_countries','status','id'])
df.head()
df
# Out:
#        adult    budget original_language popularity release_date      revenue  \
# 0      False  30000000                en  21.946943   1995-10-30  373554033.0
# 1      False  65000000                en  17.015539   1995-12-15  262797249.0
# 2      False         0                en    11.7129   1995-12-22          0.0
# 3      False  16000000                en   3.859495   1995-12-22   81452156.0
# 4      False         0                en   8.387519   1995-02-10   76578911.0
# ...      ...       ...               ...        ...          ...          ...
# 45461  False         0                fa   0.072051          NaN          0.0
# 45462  False         0                tl   0.178241   2011-11-17          0.0
# 45463  False         0                en   0.903007   2003-08-01          0.0
# 45464  False         0                en   0.003503   1917-10-21          0.0
# 45465  False         0                en   0.163015   2017-06-09          0.0
#
# ...

# %%
df.isnull().sum()
# Out:
# adult                  0
# budget                 0
# original_language     10
# popularity             0
# release_date          78
# revenue                0
# runtime              251
# video                  0
# vote_average           0
# vote_count             0
# dtype: int64

# %%
df=df.dropna(subset=["original_language"])
df["runtime"] = df["runtime"].fillna(df["runtime"].mean())
df=df.drop(columns=["release_date"])
df.head()
# Out:
#    adult    budget original_language popularity      revenue  runtime  video  \
# 0  False  30000000                en  21.946943  373554033.0     81.0  False
# 1  False  65000000                en  17.015539  262797249.0    104.0  False
# 2  False         0                en    11.7129          0.0    101.0  False
# 3  False  16000000                en   3.859495   81452156.0    127.0  False
# 4  False         0                en   8.387519   76578911.0    106.0  False
#
#    vote_average  vote_count
# 0           7.7      5415.0
# 1           6.9      2413.0
# 2           6.5        92.0
# 3           6.1        34.0
# 4           5.7       173.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45004 entries, 0 to 45465
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   adult              45004 non-null  object
#  1   budget             45004 non-null  object
#  2   original_language  45004 non-null  object
#  3   popularity         45004 non-null  object
#  4   revenue            45004 non-null  float64
#  5   runtime            45004 non-null  float64
#  6   video              45004 non-null  object
#  7   vote_average       45004 non-null  float64
#  8   vote_count         45004 non-null  float64
# dtypes: float64(4), object(5)
# memory usage: 3.4+ MB

# %%
df["budget"] = df["budget"].astype(int)

# %%
df = df[df["budget"] != 0]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8865 entries, 0 to 45422
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   adult              8865 non-null   object
#  1   budget             8865 non-null   int32
#  2   original_language  8865 non-null   object
#  3   popularity         8865 non-null   object
#  4   revenue            8865 non-null   float64
#  5   runtime            8865 non-null   float64
#  6   video              8865 non-null   object
#  7   vote_average       8865 non-null   float64
#  8   vote_count         8865 non-null   float64
# dtypes: float64(4), int32(1), object(4)
# memory usage: 657.9+ KB

# %%
df["popularity"] = df["popularity"].astype(float)

# %%
from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()

categorical_cols=["adult",'original_language',"video"]

for col in categorical_cols:
    df[col]=le.fit_transform(df[col])

df.head()
# Out:
#    adult    budget  original_language  popularity      revenue  runtime  \
# 0      0  30000000                 12   21.946943  373554033.0     81.0
# 1      0  65000000                 12   17.015539  262797249.0    104.0
# 3      0  16000000                 12    3.859495   81452156.0    127.0
# 5      0  60000000                 12   17.924927  187436818.0    170.0
# 6      0  58000000                 12    6.677277          0.0    127.0
#
#    video  vote_average  vote_count
# 0      0           7.7      5415.0
# 1      0           6.9      2413.0
# 3      0           6.1        34.0
# 5      0           7.7      1886.0
# 6      0           6.2       141.0

# %%
df['profit']=df['revenue']-df['budget']

# %%
df.head()
# Out:
#    adult    budget  original_language  popularity      revenue  runtime  \
# 0      0  30000000                 12   21.946943  373554033.0     81.0
# 1      0  65000000                 12   17.015539  262797249.0    104.0
# 3      0  16000000                 12    3.859495   81452156.0    127.0
# 5      0  60000000                 12   17.924927  187436818.0    170.0
# 6      0  58000000                 12    6.677277          0.0    127.0
#
#    video  vote_average  vote_count       profit
# 0      0           7.7      5415.0  343554033.0
# 1      0           6.9      2413.0  197797249.0
# 3      0           6.1        34.0   65452156.0
# 5      0           7.7      1886.0  127436818.0
# 6      0           6.2       141.0  -58000000.0

# %%
df["success"] = (df["profit"] > 0).astype(int)

# %%
df.head()
# Out:
#    adult    budget  original_language  popularity      revenue  runtime  \
# 0      0  30000000                 12   21.946943  373554033.0     81.0
# 1      0  65000000                 12   17.015539  262797249.0    104.0
# 3      0  16000000                 12    3.859495   81452156.0    127.0
# 5      0  60000000                 12   17.924927  187436818.0    170.0
# 6      0  58000000                 12    6.677277          0.0    127.0
#
#    video  vote_average  vote_count       profit  success
# 0      0           7.7      5415.0  343554033.0        1
# 1      0           6.9      2413.0  197797249.0        1
# 3      0           6.1        34.0   65452156.0        1
# 5      0           7.7      1886.0  127436818.0        1
# 6      0           6.2       141.0  -58000000.0        0

# %%
x=df.drop(columns=['success','revenue','profit'])
y=df.success

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=41)

# %%
from sklearn import linear_model
from sklearn.linear_model import LogisticRegression
model1=linear_model.LogisticRegression()
model1.fit(x_train,y_train)
# Out:
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model1.score(x_test,y_test)
# Out:
# 0.7529610829103215

# %%
from sklearn import tree 
from sklearn.tree import DecisionTreeClassifier

# %%
model2=DecisionTreeClassifier()
model2.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
model2.score(x_test,y_test)
# Out:
# 0.7033276931754089

# %%
df["success"].value_counts()
# Out:
# success
# 0    5110
# 1    3755
# Name: count, dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier
model3=RandomForestClassifier(n_estimators=20)
model3.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=20)

# %%
model3.score(x_test,y_test)
# Out:
# 0.763677382966723

# %%
import pickle

name='trained_movie_model2.sav'
pickle.dump(model3,open(name,'wb'))

# %%
feature_columns = x_train.columns  # or X_test.columns

importances = model2.feature_importances_
feature_importance_df = pd.DataFrame({'Feature': feature_columns, 'Importance': importances})
print(feature_importance_df.sort_values(by="Importance", ascending=False))
# Out:
#              Feature  Importance
# 7         vote_count    0.483635
# 3         popularity    0.142638
# 6       vote_average    0.118875
# 4            runtime    0.117548
# 1             budget    0.107382
# 2  original_language    0.029922
# 0              adult    0.000000
# 5              video    0.000000

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

def evaluate_model(y_true, y_pred):
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted')  # Use 'weighted' for multiclass
    recall = recall_score(y_true, y_pred, average='weighted')
    f1 = f1_score(y_true, y_pred, average='weighted')

    print(f"Accuracy: {accuracy*100}")
    print(f"Precision: {precision*100}")
    print(f"Recall: {recall*100}")
    print(f"F1-Score: {f1*100}")

    return accuracy, precision, recall, f1

# %%
# Example usage with a trained model
y_pred1 = model1.predict(x_test)
y_pred2 = model2.predict(x_test)
y_pred3 = model3.predict(x_test)

print("LogisticRegression Metrics:")
evaluate_model(y_test, y_pred1)

print("\n DecisionTree Metrics:")
evaluate_model(y_test, y_pred2)

print("\n RandomForest Metrics:")
evaluate_model(y_test, y_pred3)
# Out:
# LogisticRegression Metrics:
# Accuracy: 75.29610829103216
# Precision: 76.27238801088492
# Recall: 75.29610829103216
# F1-Score: 74.2537721950106
#
#  DecisionTree Metrics:
# Accuracy: 70.3327693175409
# Precision: 70.27298244732614
# Recall: 70.3327693175409
# F1-Score: 70.29963677128356
#
#  RandomForest Metrics:
# Accuracy: 76.3677382966723
# Precision: 76.33694233039012
# Recall: 76.3677382966723
# F1-Score: 76.01542396258694
# (0.763677382966723, 0.7633694233039012, 0.763677382966723, 0.7601542396258694)

# %%
df.columns
# Out:
# Index(['adult', 'budget', 'original_language', 'popularity', 'revenue',
#        'runtime', 'video', 'vote_average', 'vote_count', 'profit', 'success'],
#       dtype='object')
